# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
clrimage=cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\sample_640×426.jpeg")
plt.imshow(clrimage)
plt.title("Original Image")
plt.axis('off')
plt.show()
#note how

# %%
image=cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\sample_640×426.jpeg",cv2.IMREAD_GRAYSCALE)

# %%
print("Image Shape:",image.shape)
print("Pixel Value at (0,0):",image[40][40])
# Out:
# Image Shape: (426, 640)
# Pixel Value at (0,0): 109

# %%
clrimage1=cv2.cvtColor(clrimage,cv2.COLOR_BGR2GRAY)
plt.imshow(clrimage1,cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')
plt.show()

# %%
iamge=cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\sample_640×426.jpeg")
rgb_image=cv2.cvtColor(iamge,cv2.COLOR_BGR2RGB)
gray_image=cv2.cvtColor(iamge,cv2.COLOR_BGR2GRAY)
_,binary_image=cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)

# %%
print("IMAGE PROPERTIES")
print("RGB Image Shape:(Height,width,channel)",rgb_image.shape)
print("Gray Image Shape:",gray_image.shape)
print("Image data type:",rgb_image.dtype)
print("Total number of pixels:",rgb_image.size)
print("Pixel value range: ",rgb_image.min(),"to",rgb_image.max())
print("Average pixel intensity",np.mean(iamge))
# Out:
# IMAGE PROPERTIES
# RGB Image Shape:(Height,width,channel) (426, 640, 3)
# Gray Image Shape: (426, 640)
# Image data type: uint8
# Total number of pixels: 817920
# Pixel value range:  0 to 255
# Average pixel intensity 105.25422046165885

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(rgb_image)
plt.title("Rgb image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(gray_image)
plt.title("Gray image")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(binary_image,cmap='gray')
plt.title("Binary image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(425.5), np.float64(-0.5))

# %%
#write a code to import an image and convert the image to 7 different types and display them using subplots
image_path="C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\sample_640×426.jpeg"
image=cv2.imread(image_path)
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
lab=cv2.cvtColor(image,cv2.COLOR_BGR2Lab)
ycrb=cv2.cvtColor(image,cv2.COLOR_BGR2YCrCb)
aplha_channel=cv2.cvtColor(image,cv2.COLOR_BGR2BGRA)
#image.shape gives height,width,channels
plt.figure(figsize=(16,8))
plt.subplot(2,4,1)
plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis("off")

plt.subplot(2,4,2)
plt.imshow(gray,cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")

plt.subplot(2,4,3)
plt.imshow(rgb)
plt.title("RGB Image")
plt.axis("off")

plt.subplot(2,4,4)
plt.imshow(hsv)
plt.title("HSV Image")
plt.axis("off")

plt.subplot(2,4,5)
plt.imshow(lab)
plt.title("Lab Image")
plt.axis("off")

plt.subplot(2,4,6)
plt.imshow(ycrb)
plt.title("YCrCb Image")
plt.axis("off")

plt.subplot(2,4,7)
plt.imshow(aplha_channel)
plt.title("Alpha Channel Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(425.5), np.float64(-0.5))

# %%
#class 10

image=cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\sample_640×426.jpeg")
image1=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

print("Image Shape:",image.shape)

b,g,r=image[100][100]

print("Pixel Value at (100,100): B:",b," G:",g," R:",r)

r,g,b=image1[100][100]

print("Pixel Value at (100,100): R:",r," G:",g," B:",b)

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.imshow(image1)
plt.title("RGB Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(image)
plt.title("BGR Image")
plt.axis("off")
plt.show()
# display individual pixel values for a specific pixel in both RGB and BGR formats
# Out:
# Image Shape: (426, 640, 3)
# Pixel Value at (100,100): B: 119  G: 96  R: 140
# Pixel Value at (100,100): R: 140  G: 96  B: 119

# %%
#use case: detetcting specific color in an image
image=cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\image.png")
image1=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV)

lower_red=np.array([0,120,70])
upper_red=np.array([10,255,255])

mask=cv2.inRange(hsv,lower_red,upper_red)
result=cv2.bitwise_and(image1,image1,mask=mask)

plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(image1)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(mask,cmap='gray')
plt.title("input image in red mask")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(result)
plt.title("Detected Red Color")
plt.axis("off")
plt.show()

#

# %%
# use case: detecting yellow color in an image

import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread("C:\\Users\\KARUN NAGARAJ\\Downloads\\advanced python\\image.png")

# Convert for correct display
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Convert to HSV for color detection
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# HSV range for yellow color
lower_yellow = np.array([20, 100, 100])
upper_yellow = np.array([35, 255, 255])

# Create mask for yellow color
mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

# Extract yellow regions
result = cv2.bitwise_and(image_rgb, image_rgb, mask=mask)

# Visualization
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(mask, cmap="gray")
plt.title("Input Image in Yellow Mask")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(result)
plt.title("Detected Yellow Color")
plt.axis("off")

plt.show()
