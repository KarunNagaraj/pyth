# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread('image.png')
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
hist=cv2.calcHist([image_gray],[0],None,[256],[0,256])
plt.figure()
plt.title("Grayscale Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
plt.plot(hist)
plt.xlim([0,256])
plt.show()

# %%
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
colors=('b','g','r')
plt.figure()
plt.title("Color Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixels")
for i,col in enumerate(colors):
    hist=cv2.calcHist([image_rgb],[i],None,[256],[0,256])
    plt.plot(hist,color=col)
    plt.xlim([0,256])

# %%
image=cv2.imread('image.png',cv2.IMREAD_GRAYSCALE)
equalized=cv2.equalizeHist(image)
plt.figure()
plt.subplot(2,2,1)
plt.imshow(image,cmap='gray')
plt.title("Original Image")
plt.subplot(2,2,2)
plt.imshow(equalized,cmap='gray')
plt.title("Equalized Image")
plt.subplot(2,2,3)
plt.hist(image.ravel(),256,[0,256])
plt.subplot(2,2,4)
plt.hist(equalized.ravel(),256,[0,256])
plt.show()
# Out:
# C:\Users\KARUN NAGARAJ\AppData\Local\Temp\ipykernel_8388\3169922328.py:11: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(image.ravel(),256,[0,256])
# C:\Users\KARUN NAGARAJ\AppData\Local\Temp\ipykernel_8388\3169922328.py:13: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(equalized.ravel(),256,[0,256])

# %%
#segmentation
image=cv2.imread('image.png')
img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
ret, thresh1 = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(gray, 127, 255, cv2.THRESH_OTSU)
ret, thresh4 = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.figure(figsize=(10,10))
plt.subplot(2,3,1)
plt.imshow(img)
plt.title("Original Image")
plt.subplot(2,3,2)
plt.imshow(thresh, cmap='gray') 
plt.subplot(2,3,3)
plt.imshow(thresh1, cmap='gray')
plt.subplot(2,3,4)
plt.imshow(thresh2, cmap='gray')
plt.subplot(2,3,5)
plt.imshow(thresh3, cmap='gray')
plt.subplot(2,3,6)
plt.imshow(thresh4, cmap='gray')
